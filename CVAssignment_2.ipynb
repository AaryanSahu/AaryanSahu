# %% [markdown]
# <a href="https://colab.research.google.com/github/AaryanSahu/AaryanSahu/blob/main/CVAssignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gesture Detection Assignment 2
# 1. Make a copy of this notebook and solve.
# 2. If you have any doubts, feel free to ask us

# %%
from google.colab.patches import cv2_imshow # traditional cv2.imshow doesnot work in colab
import numpy as np
import matplotlib.pyplot as plt

# %%
# cv2_imshow examples
gray_img = np.random.uniform(0, 255, (100, 100))
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=100x100 at 0x7F3D193E9450>

# %%
# show a color image

# A color image is a three channel matrix
color_img = np.random.uniform(0, 255, (100, 100, 3))
cv2_imshow(color_img)

# Explore more about the cv2_imshow function
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F3D1015AA50>

# %% [markdown]
# ## Question 1
# Image is a 2d array, where each element is a value ranging from 0 to 255. Generate an image (400 * 400) of the following shapes using numpy array and display it using cv2_imshow
#
# 1. Rectangle which is 10 pixels wide
# 2. A Spiral with maximum radius of 150 pixels, with 10 pixel width.
# 3. A Simple Smiley Face.

# %% [markdown]
# As an example a circle which a 10 pixel width is plotted

# %%
circle = np.ones((400, 400)) * 255
for theta in np.arange(0, 2*np.pi, 0.01):
    for r in np.arange(150, 160, 1):
        x = 200 + r * np.cos(theta)
        y = 200 + r * np.sin(theta)

        circle[int(x)][int(y)] = 0
cv2_imshow(circle)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F3D193E93D0>

# %%
# Question 1A

# %%
# Question 1B

# %% [markdown]
# Try to use this image as a template. Be creative!!
#
# ![image.png](data:image/png;base64,...)

# %%
# Question 1C

# %% [markdown]
# ## Color Image Generation
# Generate a Color Image of a stacked rectangle as shown below. Show your creativity and impress us with your creativity!

# %% [markdown]
# As an example, take a look at this:
#
# ![image.png](data:image/png;base64,...)
